# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/okfn/dataportals.org/master/data/portals.csv')

# %%
df.columns
# Out:
# Index([u'name', u'title', u'url', u'author', u'publisher', u'issued',
#        u'publisher_classification', u'description', u'tags', u'license_id',
#        u'license_url', u'place', u'location', u'country', u'language',
#        u'status', u'metadatacreated', u'generator', u'api_endpoint',
#        u'api_type', u'full_metadata_download'],
#       dtype='object')

# %%
data = df.groupby('country').sum()

# %%
data
# Out:
#                                                        name  \
# country
# AE                                            uae_open_data
# AF                                         africa_open_data
# AL                                                  albania
# AR        buenos-airesdat-ar---unofficial-argentina's-op...
# AT        at-vorarlbergdata-catalogue-austrian-governmen...
# AU        australian-antarctic-data-centreaustralian-dat...
# BE                     gentopendata-brussel-bepublicdata-be
# BG           портал-за-отворени-данни-на-република-българия
# BH                                 bahrainbahrain-open-data
# BM                                               bermuda_io
# BR        ckan-brazildados-al-gov-bremap-fundacao-getuli...
# CA        alberta_cabanffopendata_cabrampton_cabrandon_m...
# CH                                 portal_der_stadt_zuerich
# CL        chile_library_of_congresschile_transparency_bo...
# CM                               cameroon_opendataforafrica
# CN        beijing-commission-of-economy-and-information-...
# CO                                       open-data-colombia
# CV                              capeverde_opendataforafrica
# CZ                                              cz-ckan-net
# DE        berlin-open-datadata-ulmdaten-baden-wurttember...
# DK                                           digitaliser_dk
# DZ                                algeria_opendataforafrica
# ES        ajuntament-de-tarragonaajuntament-de-terassaan...
# EU                  mindbigdata-the-"mnist"-of-brain-digits
# Europe                               eutransparencysemic_eu
# FI        finlandhelsinki_finlandjyvaskyla_finlandnation...
# FR        angersbouche-rhone-visitprovencecub-bordeauxda...
# GB        allerdalebirmingham-ukdata_gov_ukdata-lincolnd...
# GLOBAL    earthworks---stanford-university-libraries-geo...
# GR                                           geodata_gov_gr
# ...                                                     ...
# XK                                         open-data-kosovo
# ZM                                 zambia_opendataforafrica
# ZW                               zimbabwe_opendataforafrica
# bf                                              data-gov-bf
# br        dados-gov-brdados-gov-novo-hamburgo-brasildado...
# cod                               drcongo_opendataforafrica
# cog                                rcongo_opendataforafrica
# dnk                                            odaa_denmark
# eTH                              ethiopia_opendataforafrica
# en                                                vernon_bc
# gha                                 ghana_opendataforafrica
# global                             linked-clean-energy-data
# gr                                            datagovgreece
# isr                                             data_gov_il
# jp                                                data-meti
# mAR                               morocco_opendataforafrica
# moz                            mozambique_opendataforafrica
# mwi                                malawi_opendataforafrica
# mx uy cl                                              criik
# nam                               namibia_opendataforafrica
# nga                               nigeria_opendataforafrica
# no                                            data-norge-no
# pe                                                datosperu
# ru                                               datagov-ru
# rwa                                rwanda_opendataforafrica
# ssd                            southsudan_opendataforafrica
# sui                        data-catalogue-suisse-government
# tun                               tunisia_opendataforafrica
# tza                              tanzania_opendataforafrica
# zaf                           southafrica_opendataforafrica
#
#                                                       title  \
# country
# AE                                            UAE Open Data
# AF                                         Africa Open Data
# AL                                        Open Data Albania
# AR        Buenos Aires Datadat.ar - Unofficial Argentina...
# AT        Vorarlbergdata.gv.at - Offene Daten Österreich...
# AU        Australian Antarctic Data CentreAustralian Dat...
# BE        Gent Data CatalogueOpendata.brussel.be - Offic...
# BG           Портал за отворени данни на Република България
# BH        Open Data Platform of the Kingdom of BahrainBa...
# BM                                               Bermuda.io
# BR        CKAN BrazilAlagoas em Dados e Informações - Of...
# CA        AlbertaBanff, AlbertaBrampton, OntarioCity of ...
# CH                                  Portal der Stadt Zürich
# CL        Chile Library of Congress Linked DataChile's T...
# CM                                   Open Data for Cameroon
# CN        北京市政务数据资源网Chinese Government Public Informatio...
# CO              Catálogo de Datos del Estado Colombiano\r\n
# CV                                 Open Data for Cape Verde
# CZ                                      CKAN Czech Republic
# DE        Berlin Open DataDatenkatalog UlmBaden-Württemb...
# DK                                    Danish Data Catalogue
# DZ                                    Open Data for Algeria
# ES        Open Data TarragonaOpen Data TerassaAndalusia ...
# EU                  MindBigData The "MNIST" of Brain Digits
# Europe    European Open Data InventorySemantic Interoper...
# FI        Finnish national data catalogue (beta)Helsinki...
# FR        Angers Loire Metropol Data CatalogBouche-Rhone...
# GB        Allerdale Open DataBirmingham Open DataData.go...
# GLOBAL    EarthWorks - Stanford University Libraries geo...
# GR                                           geodata.gov.gr
# ...                                                     ...
# XK                                         Open Data Kosovo
# ZM                                     Open Data for Zambia
# ZW                                   Open Data for Zimbabwe
# bf                                              Data.gov.bf
# br        dados.gov.brNovo Hamburgo, Rio Grande do Sul, ...
# cod              Open Data for Democratic Republic of Congo
# cog                         Open Data for Republic of Congo
# dnk                                        Open Data Aarhus
# eTH                                  Open Data for Ethiopia
# en                                 Vernon, British Columbia
# gha                                     Open Data for Ghana
# global          Linked Clean Energy Data - data.reegle.info
# gr                              Greece National Data Portal
# isr                                                  gov.il
# jp                                    Open Data METI, Japan
# mAR                                   Open Data for Morocco
# moz                                Open Data for Mozambique
# mwi                                    Open Data for Malawi
# mx uy cl                                              criik
# nam                                   Open Data for Namibia
# nga                                   Open Data for Nigeria
# no                                            data.norge.no
# pe                                            datosperu.org
# ru                                               DataGov.ru
# rwa                                    Open Data for Rwanda
# ssd                               Open Data for South Sudan
# sui                        Offene Behördendaten der Schweiz
# tun                                   Open Data for Tunesia
# tza                                  Open Data for Tanzania
# zaf                              Open Data for South Africa
#
#                                                         url  \
# country
# AE              http://www.government.ae/web/guest/uae-data
# AF                               http://africaopendata.org/
# AL                                     http://open.data.al/
# AR        http://data.buenosaires.gob.ar/http://datar.no...
# AT        http://data.vorarlberg.gv.at/http://data.gv.at...
# AU        https://www1.data.antarctica.gov.auhttp://ada....
# BE        http://data.gent.behttp://opendata.brussel.be/...
# BG                           http://opendata.government.bg/
# BH        http://www.bahrain.bh/wps/portal/data/http://w...
# BM                                       http://bermuda.io/
# BR        http://br.ckan.net/http://dados.al.gov.brhttp:...
# CA        http://data.alberta.ca/http://www.banffopendat...
# CH        http://data.stadt-zuerich.ch/content/portal/de...
# CL        http://datos.bcn.cl/http://www.consejotranspar...
# CM                   http://cameroon.opendataforafrica.org/
# CN        http://www.bjdata.gov.cn/http://govinfo.nlc.go...
# CO                                 http://www.datos.gov.co/
# CV                  http://caboverde.opendataforafrica.org/
# CZ                                      http://cz.ckan.net/
# DE        http://daten.berlin.de/http://data.ulm.de/http...
# DK                               http://data.digitaliser.dk
# DZ                    http://algeria.opendataforafrica.org/
# ES        http://opendata.tarragona.cat/http://opendata....
# EU                        http://www.mindbigdata.com/opendb
# Europe    http://ckan.net/tag/read/eutransparencyhttp://...
# FI        http://beta.avoindata.fi/http://www.hri.fihttp...
# FR        http://data.angers.fr/http://data.visitprovenc...
# GB        http://www.allerdale.gov.uk/default.aspx?Page=...
# GLOBAL    https://earthworks.stanford.eduhttp://opendata...
# GR                           http://geodata.gov.gr/geodata/
# ...                                                     ...
# XK                          http://opendatakosovo.org/data/
# ZM                     http://zambia.opendataforafrica.org/
# ZW                   http://zimbabwe.opendataforafrica.org/
# bf                                      http://data.gov.bf/
# br        http://dados.gov.br/http://dados.novohamburgo....
# cod                   http://drcongo.opendataforafrica.org/
# cog                    http://rcongo.opendataforafrica.org/
# dnk                                     http://www.odaa.dk/
# eTH                  http://ethiopia.opendataforafrica.org/
# en                                http://www.vernon.ca/map/
# gha                     http://ghana.opendataforafrica.org/
# global                             http://data.reegle.info/
# gr                                      http://data.gov.gr/
# isr                                     http://data.gov.il/
# jp                                   http://datameti.go.jp/
# mAR                   http://morocco.opendataforafrica.org/
# moz                http://mozambique.opendataforafrica.org/
# mwi                    http://malawi.opendataforafrica.org/
# mx uy cl                              http://www.criik.com/
# nam                   http://namibia.opendataforafrica.org/
# nga                   http://nigeria.opendataforafrica.org/
# no                                    http://data.norge.no/
# pe                                http://www.datosperu.org/
# ru                                       http://datagov.ru/
# rwa                    http://rwanda.opendataforafrica.org/
# ssd                http://southsudan.opendataforafrica.org/
# sui                               http://opendata.admin.ch/
# tun                   http://tunisia.opendataforafrica.org/
# tza                  http://tanzania.opendataforafrica.org/
# zaf               http://southafrica.opendataforafrica.org/
#
#                                                       place  \
# country
# AE                                     United Arab Emirates
# AF                                                   Africa
# AL                                                  Albania
# AR        Buenos Aires, ArgentinaArgentinaMisiones, Arge...
# AT        VorarlbergAustriaLinzGraz, AustriaLand Kärnten...
# AU        Australian Antarctic TerritoryAustraliaCanberr...
# BE                             GentBrussels, BelgiumBelgium
# BG                                                    Sofia
# BH                                           BahrainBahrain
# BM                                                  Bermuda
# BR        BrazilAlagoas, BrazilRio de Janeiro, BrazilRec...
# CA        Alberta, CanadaBanff, AlbertaBrampton, Ontario...
# CH                                      Zürich, Switzerland
# CL                                             ChileChilecl
# CM                                                 Cameroon
# CN                        BeijingChinaDalianShanghai, China
# CO                                         Bogota, Colombia
# CV                                               Cape Verde
# CZ                                           Czech Republic
# DE        BerlinUlmBaden-WürttembergBremenGermanyHamburg...
# DK                                       Kingdom of Denmark
# DZ                                                  Algeria
# ES        TarragonaTerrasaAndalusia, SpainAragónAsturias...
# EU                                            International
# Europe                                         EuropeEurope
# FI        FinlandHelsinkiJyväskyläFinlandOuluRepublic of...
# FR        AngersBouche-Rhone (Provence)Bordeaux, FranceF...
# GB        Allerdale, UKBirmingham (City), UKGreat Britai...
# GLOBAL                           InternationalInternational
# GR                                        Hellenic Republic
# ...                                                     ...
# XK                                                   Kosovo
# ZM                                                   Zambia
# ZW                                                 Zimbabwe
# bf                                             Burkina Faso
# br        BrazilNovo Hamburgo, Rio Grande do Sul, Brazil...
# cod                            Democratic Republic of Congo
# cog                                       Republic of Congo
# dnk                                         Aarhus, Denmark
# eTH                                                Ethiopia
# en                                 Vernon, British Columbia
# gha                                                   Ghana
# global                                               global
# gr                                                   Greece
# isr                                                  Israel
# jp                                                    Japan
# mAR                                                 Morocco
# moz                                              Mozambique
# mwi                                                  Malawi
# mx uy cl                                      South America
# nam                                                 Namibia
# nga                                                 Nigeria
# no                                   Norway / Norge / Noreg
# pe                                                     Peru
# ru                                       Russian Federation
# rwa                                                  Rwanda
# ssd                                             South Sudan
# sui                                             Switzerland
# tun                                                 Tunesia
# tza                                                Tanzania
# zaf                                            South Africa
#
#                                                      status
# country
# AE                                                   active
# AF                                                   active
# AL                                                   active
# AR                                 activeactiveactiveactive
# AT         activeactiveactiveactiveactiveactiveactiveactive
# AU        activeactiveactiveactiveactiveactiveactiveacti...
# BE                                       activeactiveactive
# BG                                                   active
# BH                                         inactiveinactive
# BM                                                   active
# BR                                 activeactiveactiveactive
# CA        activeactiveactiveactiveactiveactiveactiveacti...
# CH                                                   active
# CL                                       activeactiveactive
# CM                                                   active
# CN                                 activeactiveactiveactive
# CO                                                   active
# CV                                                   active
# CZ                                                   active
# DE        activeactiveactiveactiveactiveactiveactiveacti...
# DK                                                   active
# DZ                                                   active
# ES        activeactiveactiveactiveactiveactiveactiveacti...
# EU                                                   active
# Europe                                         activeactive
# FI         activeactiveactiveactiveactiveactiveactiveactive
# FR        activeactiveactiveactiveactiveactiveactiveacti...
# GB        activeactiveactiveactiveactiveactiveactiveacti...
# GLOBAL                                         activeactive
# GR                                                   active
# ...                                                     ...
# XK                                                   active
# ZM                                                   active
# ZW                                                   active
# bf                                                   active
# br                                 activeactiveactiveactive
# cod                                                  active
# cog                                                  active
# dnk                                                  active
# eTH                                                  active
# en                                                   active
# gha                                                  active
# global                                               active
# gr                                                   active
# isr                                                  active
# jp                                                   active
# mAR                                                  active
# moz                                                  active
# mwi                                                  active
# mx uy cl                                             active
# nam                                                  active
# nga                                                  active
# no                                                   active
# pe                                                   active
# ru                                                   active
# rwa                                                  active
# ssd                                                  active
# sui                                                  active
# tun                                                  active
# tza                                                  active
# zaf                                                  active
#
# [112 rows x 5 columns]
